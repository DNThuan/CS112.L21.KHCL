# %%
from os import spawnl
import numpy as np
from numpy.core.defchararray import split
from scipy.optimize import linear_sum_assignment


def miniminzation_time(arr):
    row_ind ,col_ind = linear_sum_assignment(arr)
    tc=cost_matrix[row_ind,col_ind].sum()
    return tc

'''
cost_matrix = np.array([[9,2,7,8],
                        [6,4,3,7],
                        [5,8,1,8],
                        [7,6,9,4]])
'''

matrix=[]
# j (job)
# p (person)
p,j=map(int,input().split())

for _ in range(p):
    lst=list(map(int,input().split()))
    matrix.append(lst)

cost_matrix=np.array(matrix)

print(miniminzation_time(cost_matrix))
# Out:
# 2 3
# 1 2 3
# 4 5 6
# 6
