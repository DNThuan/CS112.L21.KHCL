# %% [markdown]
# # 1.Abstraction
#   Từ mảng nhập vào, sắp xếp mảng giảm dần và đếm số phần tử có giá trị lớn hơn hoặc bằng số thứ tự của nó trong mảng.

# %% [markdown]
# # 2.Pattern Recognition
# cần phải xét hết các phần tử trong mảng nên ta dùng thuật toán vét cạn.

# %% [markdown]
# # 3. Algorithm

# %% [markdown]
# ```
# A = list[]
# A.sort()
# Count = 0
# for i in range(len(A)):
#    If ( A[i] >= i+1):
#        Count+=1
# print(Count)
#
# ```

# %% [markdown]
# # 4. Đánh giá độ phức tạp
# Thuật toán có độ phức tạp là O(nlog(n)+n)

# %% [markdown]
# # 5.Programming

# %%
n = int(input())
a = list(map(int, input().split()))
b = sorted(a, reverse=True)
count = 0
for i in range(0,n):
  if b[i] >= i+1 :
    count+=1
print(count)
